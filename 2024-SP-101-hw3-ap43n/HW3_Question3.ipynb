# %% [markdown]
# #### Download the Pascal-VOC dataset from [here](http://host.robots.ox.ac.uk/pascal/VOC/voc2012/index.html#devkit)

# %%
import torch
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as T
from torch.utils.data import DataLoader, random_split

import matplotlib.pyplot as plt

# %% [markdown]
# ## Section 1: Load Pascal-VOC dataset

# %%
import os
import cv2
import numpy as np
from xml.etree import ElementTree as ET
from torchvision import transforms
import collections

train_dir = 'train_dir/VOCdevkit/VOC2012'
test_dir = 'test_dir/VOCdevkit/VOC2012'

PASCAL_CLASSES = ['aeroplane', 'bicycle', 'bird', 'boat', 'bottle',
                    'bus', 'car', 'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse',
                    'motorbike', 'person', 'pottedplant', 'sheep', 'sofa', 'train', 'tvmonitor']

class PascalVOCDataset(torch.utils.data.Dataset):
  def __init__(self, train_dir, width, height, transforms=None):
    self.transforms = transforms
    self.train_dir = train_dir
    self.height = height
    self.width = width
  
    self.classes = ['aeroplane', 'bicycle', 'bird', 'boat', 'bottle',
                    'bus', 'car', 'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse',
                    'motorbike', 'person', 'pottedplant', 'sheep', 'sofa', 'train', 'tvmonitor']

    self.img_paths = list(sorted(os.listdir(os.path.join(self.train_dir, "JPEGImages"))))
    self.ann_paths = list(sorted(os.listdir(os.path.join(self.train_dir, "Annotations")))) 

  def __getitem__(self, idx):
    try:
      img_path = os.path.join(self.train_dir, "JPEGImages", self.img_paths[idx])
      ann_path = os.path.join(self.train_dir, "Annotations", self.ann_paths[idx])

      #TODO: Converting image to correct size
      img_color = torchvision.io.read_image(img_path)
      img_res = torchvision.transforms.functional.resize(img_color, [480,480],antialias=True)
      img_res = torch.div(img_res,255.0)    

      #TODO Extract the necessary information from xml files - bounding box coordinates, label, area, image_id
      target = {"bndboxes": [], "labels" : [], "area" : [], "image_id" : []}
      boxes = []
      labels = []
      areas = []
      image_id = []

      tree = ET.parse(ann_path)
      root = tree.getroot()

      height = img_res.shape[1]
      width = img_res.shape[2]

      for obj in root.iter("object"):
        label = obj.find("name").text
        bounding_box = obj.find("bndbox")
        x_min = int(float(bounding_box.find("xmin").text))
        y_min = int(float(bounding_box.find("ymin").text))
        x_max = int(float(bounding_box.find("xmax").text))
        y_max = int(float(bounding_box.find("ymax").text))

        xmin = (x_min/width)*self.width
        xmax = (x_max/width)*self.width
        ymin = (y_min/height)*self.height
        ymax = (y_max/height)*self.height

        boxes.append([xmin, ymin, xmax, ymax])
        labels.append(self.classes.index(label))
        areas.append((x_max - x_min) * (y_max - y_min))
      
      boxes = torch.tensor(boxes, dtype=torch.float32)
      labels = torch.tensor(labels, dtype=torch.int64)
      areas = torch.tensor(areas, dtype=torch.float32)
      image_id = idx

      target = {"boxes": boxes, "labels" : labels, "area" : areas, "image_id" : image_id, "iscrowd":torch.tensor([0]*len(labels))}
    except Exception as e:
        print(f"Error at index {idx}: {e}")
        raise e

    return img_res, target

  def __len__(self):
    return len(self.img_paths)

# %% [markdown]
# ## Section 2: Define Pre-trained Object Detection Model

# %%
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
#import other models as well

def getPretrainedModel(num_classes):
  #TODO: load a pre-trained model and replace the pre-trained head with a new one.
  model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
  for param in model.parameters():
    param.requires_grad = False
  in_features = model.roi_heads.box_predictor.cls_score.in_features
  model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
  
  return model

# %% [markdown]
# ## Section 3: Prepare Dataset and Train the model

# %%
traindataset = PascalVOCDataset(train_dir, 480, 480, transforms = T.ToTensor())
subset_indices = range(1000)
traindataset = torch.utils.data.Subset(traindataset, subset_indices)


torch.manual_seed(1)
# TODO: split the dataset in train and test set
train_size = int(0.8 * len(traindataset))
test_size = len(traindataset) - train_size
train_data, test_data = random_split(traindataset, [train_size, test_size])
print(f'Length of traindata -- {len(train_data)} and testdata -- {len(test_data)}')

def collate_fn(data):
    images = []
    targets = []
    for i in data:
      images.append(i[0])
      targets.append(i[1])
    return torch.utils.data.default_collate(images), targets

batchSize = 5

trainloader = torch.utils.data.DataLoader(train_data, batch_size=batchSize, shuffle=True, num_workers=2, collate_fn=collate_fn)
testloader = torch.utils.data.DataLoader(test_data, batch_size=batchSize, shuffle=False, num_workers=2, collate_fn=collate_fn)
# Out:
# Length of traindata -- 800 and testdata -- 200

# %%
# these are the helper libraries imported.
# !git clone https://github.com/pytorch/vision.git
# Out:
# fatal: destination path 'vision' already exists and is not an empty directory.

# %%
# !cp vision/references/detection/utils.py ./
# !cp vision/references/detection/transforms.py ./
# !cp vision/references/detection/coco_eval.py ./
# !cp vision/references/detection/engine.py ./
# !cp vision/references/detection/coco_utils.py ./

# %%
from engine import train_one_epoch, evaluate

#TODO: Declare your hyperparameters
lr = 0.001
w_d = 0.0005
num_classes = 20
PATH_TO_FASTER_RCNN = "./FasterRCNN.pt"

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

model = getPretrainedModel(num_classes)
model.to(device)

params = [p for p in model.parameters() if p.requires_grad]

optimizer = torch.optim.SGD(params, lr=0.001, momentum=0.9, weight_decay=w_d)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)
num_epochs = 10
epoch_accuracies = []
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
for epoch in range(num_epochs):
    train_one_epoch(model, optimizer, trainloader, device, epoch, print_freq=10)

    lr_scheduler.step()

    evaluate(model, testloader, device=device)
# Out:
# Epoch: [0]  [  0/160]  eta: 0:04:00  lr: 0.000007  loss: 3.5687 (3.5687)  loss_classifier: 3.1011 (3.1011)  loss_box_reg: 0.2171 (0.2171)  loss_objectness: 0.1996 (0.1996)  loss_rpn_box_reg: 0.0509 (0.0509)  time: 1.5026  data: 0.1550  max mem: 1434
# Epoch: [0]  [ 10/160]  eta: 0:00:43  lr: 0.000070  loss: 3.5261 (3.4503)  loss_classifier: 3.0064 (3.0277)  loss_box_reg: 0.1640 (0.1796)  loss_objectness: 0.2135 (0.2087)  loss_rpn_box_reg: 0.0266 (0.0342)  time: 0.2924  data: 0.0272  max mem: 1450
# Epoch: [0]  [ 20/160]  eta: 0:00:32  lr: 0.000133  loss: 3.1100 (3.0535)  loss_classifier: 2.7155 (2.6418)  loss_box_reg: 0.1502 (0.1720)  loss_objectness: 0.2257 (0.2114)  loss_rpn_box_reg: 0.0208 (0.0283)  time: 0.1699  data: 0.0132  max mem: 1450
# Epoch: [0]  [ 30/160]  eta: 0:00:27  lr: 0.000196  loss: 1.8209 (2.4697)  loss_classifier: 1.4077 (2.0704)  loss_box_reg: 0.1608 (0.1747)  loss_objectness: 0.1764 (0.1982)  loss_rpn_box_reg: 0.0181 (0.0263)  time: 0.1681  data: 0.0120  max mem: 1450
# Epoch: [0]  [ 40/160]  eta: 0:00:24  lr: 0.000259  loss: 0.8940 (2.0673)  loss_classifier: 0.4048 (1.6487)  loss_box_reg: 0.1639 (0.1731)  loss_objectness: 0.1211 (0.2174)  loss_rpn_box_reg: 0.0177 (0.0280)  time: 0.1680  data: 0.0119  max mem: 1450
# Epoch: [0]  [ 50/160]  eta: 0:00:21  lr: 0.000321  loss: 0.6103 (1.7974)  loss_classifier: 0.3022 (1.3807)  loss_box_reg: 0.1534 (0.1737)  loss_objectness: 0.1247 (0.2160)  loss_rpn_box_reg: 0.0172 (0.0269)  time: 0.1691  data: 0.0122  max mem: 1450
# Epoch: [0]  [ 60/160]  eta: 0:00:19  lr: 0.000384  loss: 0.5543 (1.5930)  loss_classifier: 0.2551 (1.1924)  loss_box_reg: 0.1534 (0.1687)  loss_objectness: 0.1247 (0.2058)  loss_rpn_box_reg: 0.0152 (0.0261)  time: 0.1701  data: 0.0123  max mem: 1450
# Epoch: [0]  [ 70/160]  eta: 0:00:16  lr: 0.000447  loss: 0.5395 (1.4516)  loss_classifier: 0.2485 (1.0606)  loss_box_reg: 0.1585 (0.1679)  loss_objectness: 0.1178 (0.1976)  loss_rpn_box_reg: 0.0148 (0.0254)  time: 0.1705  data: 0.0127  max mem: 1450
# Epoch: [0]  [ 80/160]  eta: 0:00:14  lr: 0.000510  loss: 0.5446 (1.3414)  loss_classifier: 0.2447 (0.9627)  loss_box_reg: 0.1476 (0.1681)  loss_objectness: 0.0887 (0.1864)  loss_rpn_box_reg: 0.0144 (0.0241)  time: 0.1713  data: 0.0135  max mem: 1450
# Epoch: [0]  [ 90/160]  eta: 0:00:12  lr: 0.000573  loss: 0.5813 (1.2572)  loss_classifier: 0.2463 (0.8854)  loss_box_reg: 0.1476 (0.1674)  loss_objectness: 0.0979 (0.1807)  loss_rpn_box_reg: 0.0146 (0.0238)  time: 0.1706  data: 0.0132  max mem: 1450
# Epoch: [0]  [100/160]  eta: 0:00:10  lr: 0.000636  loss: 0.5295 (1.1794)  loss_classifier: 0.2463 (0.8196)  loss_box_reg: 0.1505 (0.1649)  loss_objectness: 0.0982 (0.1720)  loss_rpn_box_reg: 0.0137 (0.0228)  time: 0.1689  data: 0.0123  max mem: 1450
# Epoch: [0]  [110/160]  eta: 0:00:09  lr: 0.000698  loss: 0.5420 (1.1309)  loss_classifier: 0.2503 (0.7701)  loss_box_reg: 0.1796 (0.1666)  loss_objectness: 0.1027 (0.1712)  loss_rpn_box_reg: 0.0172 (0.0230)  time: 0.1698  data: 0.0122  max mem: 1450
# Epoch: [0]  [120/160]  eta: 0:00:07  lr: 0.000761  loss: 0.5641 (1.0882)  loss_classifier: 0.2405 (0.7280)  loss_box_reg: 0.1808 (0.1675)  loss_objectness: 0.1290 (0.1698)  loss_rpn_box_reg: 0.0236 (0.0229)  time: 0.1705  data: 0.0123  max mem: 1450
# Epoch: [0]  [130/160]  eta: 0:00:05  lr: 0.000824  loss: 0.5162 (1.0492)  loss_classifier: 0.2392 (0.6917)  loss_box_reg: 0.1611 (0.1686)  loss_objectness: 0.1290 (0.1664)  loss_rpn_box_reg: 0.0164 (0.0225)  time: 0.1712  data: 0.0136  max mem: 1450
# Epoch: [0]  [140/160]  eta: 0:00:03  lr: 0.000887  loss: 0.5270 (1.0169)  loss_classifier: 0.2435 (0.6605)  loss_box_reg: 0.1769 (0.1690)  loss_objectness: 0.1327 (0.1653)  loss_rpn_box_reg: 0.0150 (0.0222)  time: 0.1717  data: 0.0139  max mem: 1450
# Epoch: [0]  [150/160]  eta: 0:00:01  lr: 0.000950  loss: 0.5749 (0.9908)  loss_classifier: 0.2424 (0.6331)  loss_box_reg: 0.1769 (0.1697)  loss_objectness: 0.1262 (0.1661)  loss_rpn_box_reg: 0.0150 (0.0220)  time: 0.1699  data: 0.0124  max mem: 1450
# Epoch: [0]  [159/160]  eta: 0:00:00  lr: 0.001000  loss: 0.5883 (0.9666)  loss_classifier: 0.2416 (0.6103)  loss_box_reg: 0.1698 (0.1702)  loss_objectness: 0.1270 (0.1644)  loss_rpn_box_reg: 0.0163 (0.0218)  time: 0.1691  data: 0.0119  max mem: 1450
# Epoch: [0] Total time: 0:00:28 (0.1785 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:13  model_time: 0.1440 (0.1440)  evaluator_time: 0.0236 (0.0236)  time: 0.3313  data: 0.1585  max mem: 1450
# Test:  [39/40]  eta: 0:00:00  model_time: 0.1331 (0.1334)  evaluator_time: 0.0096 (0.0120)  time: 0.1596  data: 0.0120  max mem: 1450
# Test: Total time: 0:00:06 (0.1653 s / it)
# Averaged stats: model_time: 0.1331 (0.1334)  evaluator_time: 0.0096 (0.0120)
# Accumulating evaluation results...
# DONE (t=0.14s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.004
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.012
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.016
# Epoch: [1]  [  0/160]  eta: 0:00:53  lr: 0.001000  loss: 0.4548 (0.4548)  loss_classifier: 0.2039 (0.2039)  loss_box_reg: 0.1638 (0.1638)  loss_objectness: 0.0719 (0.0719)  loss_rpn_box_reg: 0.0152 (0.0152)  time: 0.3328  data: 0.1725  max mem: 1450
# Epoch: [1]  [ 10/160]  eta: 0:00:27  lr: 0.001000  loss: 0.6095 (0.5772)  loss_classifier: 0.2569 (0.2510)  loss_box_reg: 0.1878 (0.1917)  loss_objectness: 0.0774 (0.1157)  loss_rpn_box_reg: 0.0157 (0.0188)  time: 0.1865  data: 0.0273  max mem: 1450
# Epoch: [1]  [ 20/160]  eta: 0:00:25  lr: 0.001000  loss: 0.5523 (0.5361)  loss_classifier: 0.2393 (0.2302)  loss_box_reg: 0.1746 (0.1729)  loss_objectness: 0.0959 (0.1158)  loss_rpn_box_reg: 0.0120 (0.0172)  time: 0.1711  data: 0.0125  max mem: 1450
# Epoch: [1]  [ 30/160]  eta: 0:00:22  lr: 0.001000  loss: 0.4765 (0.5257)  loss_classifier: 0.2014 (0.2203)  loss_box_reg: 0.1527 (0.1670)  loss_objectness: 0.1017 (0.1191)  loss_rpn_box_reg: 0.0145 (0.0194)  time: 0.1706  data: 0.0125  max mem: 1450
# Epoch: [1]  [ 40/160]  eta: 0:00:21  lr: 0.001000  loss: 0.5109 (0.5273)  loss_classifier: 0.1995 (0.2131)  loss_box_reg: 0.1503 (0.1563)  loss_objectness: 0.1321 (0.1382)  loss_rpn_box_reg: 0.0191 (0.0197)  time: 0.1712  data: 0.0130  max mem: 1450
# Epoch: [1]  [ 50/160]  eta: 0:00:19  lr: 0.001000  loss: 0.4721 (0.5183)  loss_classifier: 0.1860 (0.2079)  loss_box_reg: 0.1282 (0.1523)  loss_objectness: 0.1419 (0.1381)  loss_rpn_box_reg: 0.0183 (0.0200)  time: 0.1732  data: 0.0134  max mem: 1450
# Epoch: [1]  [ 60/160]  eta: 0:00:17  lr: 0.001000  loss: 0.4667 (0.5196)  loss_classifier: 0.1857 (0.2075)  loss_box_reg: 0.1328 (0.1548)  loss_objectness: 0.0973 (0.1372)  loss_rpn_box_reg: 0.0158 (0.0201)  time: 0.1728  data: 0.0128  max mem: 1450
# Epoch: [1]  [ 70/160]  eta: 0:00:15  lr: 0.001000  loss: 0.5204 (0.5188)  loss_classifier: 0.1834 (0.2050)  loss_box_reg: 0.1400 (0.1541)  loss_objectness: 0.1095 (0.1397)  loss_rpn_box_reg: 0.0160 (0.0201)  time: 0.1707  data: 0.0122  max mem: 1450
# Epoch: [1]  [ 80/160]  eta: 0:00:13  lr: 0.001000  loss: 0.5478 (0.5299)  loss_classifier: 0.1931 (0.2047)  loss_box_reg: 0.1488 (0.1544)  loss_objectness: 0.1265 (0.1504)  loss_rpn_box_reg: 0.0174 (0.0205)  time: 0.1706  data: 0.0122  max mem: 1450
# Epoch: [1]  [ 90/160]  eta: 0:00:12  lr: 0.001000  loss: 0.5478 (0.5362)  loss_classifier: 0.2110 (0.2088)  loss_box_reg: 0.1560 (0.1584)  loss_objectness: 0.1142 (0.1484)  loss_rpn_box_reg: 0.0236 (0.0206)  time: 0.1706  data: 0.0122  max mem: 1450
# Epoch: [1]  [100/160]  eta: 0:00:10  lr: 0.001000  loss: 0.4945 (0.5277)  loss_classifier: 0.2082 (0.2070)  loss_box_reg: 0.1526 (0.1585)  loss_objectness: 0.0804 (0.1421)  loss_rpn_box_reg: 0.0158 (0.0201)  time: 0.1704  data: 0.0122  max mem: 1450
# Epoch: [1]  [110/160]  eta: 0:00:08  lr: 0.001000  loss: 0.5030 (0.5326)  loss_classifier: 0.1840 (0.2078)  loss_box_reg: 0.1327 (0.1582)  loss_objectness: 0.0804 (0.1460)  loss_rpn_box_reg: 0.0158 (0.0207)  time: 0.1705  data: 0.0122  max mem: 1450
# Epoch: [1]  [120/160]  eta: 0:00:06  lr: 0.001000  loss: 0.5534 (0.5354)  loss_classifier: 0.1883 (0.2065)  loss_box_reg: 0.1348 (0.1567)  loss_objectness: 0.1307 (0.1512)  loss_rpn_box_reg: 0.0212 (0.0210)  time: 0.1708  data: 0.0125  max mem: 1450
# Epoch: [1]  [130/160]  eta: 0:00:05  lr: 0.001000  loss: 0.5546 (0.5433)  loss_classifier: 0.2114 (0.2097)  loss_box_reg: 0.1494 (0.1609)  loss_objectness: 0.1221 (0.1515)  loss_rpn_box_reg: 0.0212 (0.0211)  time: 0.1708  data: 0.0124  max mem: 1450
# Epoch: [1]  [140/160]  eta: 0:00:03  lr: 0.001000  loss: 0.5904 (0.5514)  loss_classifier: 0.2203 (0.2125)  loss_box_reg: 0.1993 (0.1640)  loss_objectness: 0.1047 (0.1535)  loss_rpn_box_reg: 0.0198 (0.0214)  time: 0.1707  data: 0.0123  max mem: 1450
# Epoch: [1]  [150/160]  eta: 0:00:01  lr: 0.001000  loss: 0.5443 (0.5574)  loss_classifier: 0.1965 (0.2097)  loss_box_reg: 0.1474 (0.1607)  loss_objectness: 0.1459 (0.1653)  loss_rpn_box_reg: 0.0193 (0.0217)  time: 0.1707  data: 0.0124  max mem: 1450
# Epoch: [1]  [159/160]  eta: 0:00:00  lr: 0.001000  loss: 0.5604 (0.5613)  loss_classifier: 0.2028 (0.2114)  loss_box_reg: 0.1504 (0.1630)  loss_objectness: 0.1813 (0.1651)  loss_rpn_box_reg: 0.0192 (0.0218)  time: 0.1702  data: 0.0122  max mem: 1450
# Epoch: [1] Total time: 0:00:27 (0.1723 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:13  model_time: 0.1378 (0.1378)  evaluator_time: 0.0270 (0.0270)  time: 0.3425  data: 0.1742  max mem: 1450
# Test:  [39/40]  eta: 0:00:00  model_time: 0.1330 (0.1335)  evaluator_time: 0.0127 (0.0156)  time: 0.1626  data: 0.0118  max mem: 1450
# Test: Total time: 0:00:06 (0.1694 s / it)
# Averaged stats: model_time: 0.1330 (0.1335)  evaluator_time: 0.0127 (0.0156)
# Accumulating evaluation results...
# DONE (t=0.17s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.025
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.032
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.034
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.044
# Epoch: [2]  [  0/160]  eta: 0:00:50  lr: 0.001000  loss: 0.4672 (0.4672)  loss_classifier: 0.1891 (0.1891)  loss_box_reg: 0.1953 (0.1953)  loss_objectness: 0.0607 (0.0607)  loss_rpn_box_reg: 0.0221 (0.0221)  time: 0.3160  data: 0.1532  max mem: 1450
# Epoch: [2]  [ 10/160]  eta: 0:00:28  lr: 0.001000  loss: 0.5247 (0.5975)  loss_classifier: 0.1883 (0.1944)  loss_box_reg: 0.1548 (0.1563)  loss_objectness: 0.1288 (0.2197)  loss_rpn_box_reg: 0.0237 (0.0272)  time: 0.1869  data: 0.0274  max mem: 1450
# Epoch: [2]  [ 20/160]  eta: 0:00:25  lr: 0.001000  loss: 0.5956 (0.6681)  loss_classifier: 0.1918 (0.2133)  loss_box_reg: 0.1614 (0.1613)  loss_objectness: 0.1724 (0.2649)  loss_rpn_box_reg: 0.0237 (0.0285)  time: 0.1723  data: 0.0135  max mem: 1450
# Epoch: [2]  [130/160]  eta: 0:00:05  lr: 0.001000  loss: 0.5008 (0.5447)  loss_classifier: 0.1858 (0.1936)  loss_box_reg: 0.1356 (0.1589)  loss_objectness: 0.1539 (0.1696)  loss_rpn_box_reg: 0.0156 (0.0227)  time: 0.1709  data: 0.0125  max mem: 1450
# Epoch: [2]  [140/160]  eta: 0:00:03  lr: 0.001000  loss: 0.5219 (0.5421)  loss_classifier: 0.1888 (0.1929)  loss_box_reg: 0.1734 (0.1588)  loss_objectness: 0.1383 (0.1678)  loss_rpn_box_reg: 0.0154 (0.0226)  time: 0.1707  data: 0.0123  max mem: 1450
# Epoch: [2]  [150/160]  eta: 0:00:01  lr: 0.001000  loss: 0.5101 (0.5402)  loss_classifier: 0.1734 (0.1921)  loss_box_reg: 0.1413 (0.1578)  loss_objectness: 0.1233 (0.1680)  loss_rpn_box_reg: 0.0148 (0.0224)  time: 0.1709  data: 0.0122  max mem: 1450
# Epoch: [2]  [159/160]  eta: 0:00:00  lr: 0.001000  loss: 0.4954 (0.5363)  loss_classifier: 0.1923 (0.1923)  loss_box_reg: 0.1586 (0.1575)  loss_objectness: 0.1016 (0.1647)  loss_rpn_box_reg: 0.0142 (0.0218)  time: 0.1712  data: 0.0123  max mem: 1450
# Epoch: [2] Total time: 0:00:27 (0.1732 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:12  model_time: 0.1383 (0.1383)  evaluator_time: 0.0271 (0.0271)  time: 0.3231  data: 0.1540  max mem: 1450
# Test:  [39/40]  eta: 0:00:00  model_time: 0.1334 (0.1339)  evaluator_time: 0.0134 (0.0161)  time: 0.1641  data: 0.0120  max mem: 1450
# Test: Total time: 0:00:06 (0.1697 s / it)
# Averaged stats: model_time: 0.1334 (0.1339)  evaluator_time: 0.0134 (0.0161)
# Accumulating evaluation results...
# DONE (t=0.18s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.032
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.093
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.002
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.063
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.080
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.082
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.015
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.109
# Epoch: [3]  [  0/160]  eta: 0:00:52  lr: 0.000100  loss: 0.4405 (0.4405)  loss_classifier: 0.1759 (0.1759)  loss_box_reg: 0.1967 (0.1967)  loss_objectness: 0.0566 (0.0566)  loss_rpn_box_reg: 0.0114 (0.0114)  time: 0.3279  data: 0.1614  max mem: 1450
# Epoch: [3]  [ 10/160]  eta: 0:00:27  lr: 0.000100  loss: 0.4200 (0.4915)  loss_classifier: 0.1534 (0.1661)  loss_box_reg: 0.1455 (0.1351)  loss_objectness: 0.1038 (0.1693)  loss_rpn_box_reg: 0.0126 (0.0209)  time: 0.1850  data: 0.0259  max mem: 1450
# Epoch: [3]  [ 20/160]  eta: 0:00:24  lr: 0.000100  loss: 0.5134 (0.5366)  loss_classifier: 0.1695 (0.1871)  loss_box_reg: 0.1455 (0.1509)  loss_objectness: 0.1233 (0.1763)  loss_rpn_box_reg: 0.0154 (0.0223)  time: 0.1704  data: 0.0122  max mem: 1450
# Epoch: [3]  [ 30/160]  eta: 0:00:22  lr: 0.000100  loss: 0.4686 (0.5080)  loss_classifier: 0.1731 (0.1788)  loss_box_reg: 0.1491 (0.1517)  loss_objectness: 0.1225 (0.1559)  loss_rpn_box_reg: 0.0163 (0.0216)  time: 0.1701  data: 0.0120  max mem: 1450
# Epoch: [7]  [140/160]  eta: 0:00:03  lr: 0.000010  loss: 0.4466 (0.5241)  loss_classifier: 0.1508 (0.1828)  loss_box_reg: 0.1283 (0.1551)  loss_objectness: 0.1136 (0.1641)  loss_rpn_box_reg: 0.0143 (0.0220)  time: 0.1699  data: 0.0125  max mem: 1450
# Epoch: [7]  [150/160]  eta: 0:00:01  lr: 0.000010  loss: 0.4874 (0.5189)  loss_classifier: 0.1508 (0.1814)  loss_box_reg: 0.1426 (0.1541)  loss_objectness: 0.1136 (0.1618)  loss_rpn_box_reg: 0.0186 (0.0217)  time: 0.1708  data: 0.0126  max mem: 1450
# Epoch: [7]  [159/160]  eta: 0:00:00  lr: 0.000010  loss: 0.4584 (0.5214)  loss_classifier: 0.1553 (0.1813)  loss_box_reg: 0.1443 (0.1539)  loss_objectness: 0.1202 (0.1643)  loss_rpn_box_reg: 0.0186 (0.0218)  time: 0.1707  data: 0.0123  max mem: 1450
# Epoch: [7] Total time: 0:00:27 (0.1718 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:13  model_time: 0.1389 (0.1389)  evaluator_time: 0.0285 (0.0285)  time: 0.3463  data: 0.1750  max mem: 1450
# Test:  [39/40]  eta: 0:00:00  model_time: 0.1337 (0.1340)  evaluator_time: 0.0133 (0.0163)  time: 0.1644  data: 0.0119  max mem: 1450
# Test: Total time: 0:00:06 (0.1705 s / it)
# Averaged stats: model_time: 0.1337 (0.1340)  evaluator_time: 0.0133 (0.0163)
# Accumulating evaluation results...
# DONE (t=0.17s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.035
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.108
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.086
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.018
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.117
# Epoch: [8]  [  0/160]  eta: 0:00:52  lr: 0.000010  loss: 0.4208 (0.4208)  loss_classifier: 0.1710 (0.1710)  loss_box_reg: 0.1725 (0.1725)  loss_objectness: 0.0674 (0.0674)  loss_rpn_box_reg: 0.0099 (0.0099)  time: 0.3307  data: 0.1633  max mem: 1450
# Epoch: [8]  [ 10/160]  eta: 0:00:27  lr: 0.000010  loss: 0.4948 (0.4820)  loss_classifier: 0.1753 (0.1843)  loss_box_reg: 0.1725 (0.1640)  loss_objectness: 0.1100 (0.1165)  loss_rpn_box_reg: 0.0160 (0.0172)  time: 0.1855  data: 0.0262  max mem: 1450
# Epoch: [8]  [ 20/160]  eta: 0:00:24  lr: 0.000010  loss: 0.4922 (0.4826)  loss_classifier: 0.1612 (0.1809)  loss_box_reg: 0.1359 (0.1570)  loss_objectness: 0.1100 (0.1259)  loss_rpn_box_reg: 0.0171 (0.0189)  time: 0.1708  data: 0.0124  max mem: 1450
# Epoch: [8]  [ 30/160]  eta: 0:00:22  lr: 0.000010  loss: 0.4669 (0.5177)  loss_classifier: 0.1526 (0.1780)  loss_box_reg: 0.1338 (0.1497)  loss_objectness: 0.1340 (0.1684)  loss_rpn_box_reg: 0.0191 (0.0216)  time: 0.1707  data: 0.0123  max mem: 1450
# Epoch: [8]  [ 40/160]  eta: 0:00:20  lr: 0.000010  loss: 0.5291 (0.5279)  loss_classifier: 0.1783 (0.1821)  loss_box_reg: 0.1478 (0.1515)  loss_objectness: 0.1443 (0.1721)  loss_rpn_box_reg: 0.0216 (0.0221)  time: 0.1710  data: 0.0125  max mem: 1450
# Epoch: [8]  [140/160]  eta: 0:00:03  lr: 0.000010  loss: 0.5174 (0.5208)  loss_classifier: 0.1890 (0.1828)  loss_box_reg: 0.1587 (0.1556)  loss_objectness: 0.1599 (0.1607)  loss_rpn_box_reg: 0.0186 (0.0217)  time: 0.1703  data: 0.0126  max mem: 1450
# Epoch: [8]  [150/160]  eta: 0:00:01  lr: 0.000010  loss: 0.5193 (0.5192)  loss_classifier: 0.1675 (0.1821)  loss_box_reg: 0.1587 (0.1553)  loss_objectness: 0.1599 (0.1601)  loss_rpn_box_reg: 0.0205 (0.0217)  time: 0.1698  data: 0.0124  max mem: 1450
# Epoch: [8]  [159/160]  eta: 0:00:00  lr: 0.000010  loss: 0.5193 (0.5214)  loss_classifier: 0.1537 (0.1817)  loss_box_reg: 0.1245 (0.1539)  loss_objectness: 0.1611 (0.1640)  loss_rpn_box_reg: 0.0206 (0.0218)  time: 0.1685  data: 0.0120  max mem: 1450
# Epoch: [8] Total time: 0:00:27 (0.1723 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:13  model_time: 0.1406 (0.1406)  evaluator_time: 0.0285 (0.0285)  time: 0.3378  data: 0.1650  max mem: 1450
# Test:  [39/40]  eta: 0:00:00  model_time: 0.1340 (0.1342)  evaluator_time: 0.0133 (0.0165)  time: 0.1649  data: 0.0121  max mem: 1450
# Test: Total time: 0:00:06 (0.1708 s / it)
# Averaged stats: model_time: 0.1340 (0.1342)  evaluator_time: 0.0133 (0.0165)
# Accumulating evaluation results...
# DONE (t=0.18s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.109
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.018
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.120
# Epoch: [9]  [  0/160]  eta: 0:00:53  lr: 0.000001  loss: 0.7073 (0.7073)  loss_classifier: 0.1658 (0.1658)  loss_box_reg: 0.0656 (0.0656)  loss_objectness: 0.4391 (0.4391)  loss_rpn_box_reg: 0.0368 (0.0368)  time: 0.3317  data: 0.1654  max mem: 1450
# Epoch: [9]  [ 10/160]  eta: 0:00:28  lr: 0.000001  loss: 0.4742 (0.4989)  loss_classifier: 0.1766 (0.1788)  loss_box_reg: 0.1520 (0.1432)  loss_objectness: 0.0903 (0.1577)  loss_rpn_box_reg: 0.0164 (0.0192)  time: 0.1872  data: 0.0272  max mem: 1450
# Epoch: [9]  [ 20/160]  eta: 0:00:25  lr: 0.000001  loss: 0.4631 (0.5025)  loss_classifier: 0.1710 (0.1720)  loss_box_reg: 0.1430 (0.1398)  loss_objectness: 0.1037 (0.1715)  loss_rpn_box_reg: 0.0164 (0.0192)  time: 0.1715  data: 0.0128  max mem: 1450
# Epoch: [9]  [ 30/160]  eta: 0:00:22  lr: 0.000001  loss: 0.4586 (0.5368)  loss_classifier: 0.1534 (0.1699)  loss_box_reg: 0.1159 (0.1410)  loss_objectness: 0.1774 (0.2034)  loss_rpn_box_reg: 0.0194 (0.0225)  time: 0.1703  data: 0.0121  max mem: 1450
# Epoch: [9]  [ 40/160]  eta: 0:00:20  lr: 0.000001  loss: 0.4947 (0.5390)  loss_classifier: 0.1534 (0.1716)  loss_box_reg: 0.1159 (0.1412)  loss_objectness: 0.1774 (0.2023)  loss_rpn_box_reg: 0.0297 (0.0238)  time: 0.1704  data: 0.0121  max mem: 1450
# Epoch: [9]  [ 50/160]  eta: 0:00:19  lr: 0.000001  loss: 0.4947 (0.5277)  loss_classifier: 0.1639 (0.1744)  loss_box_reg: 0.1241 (0.1433)  loss_objectness: 0.1121 (0.1872)  loss_rpn_box_reg: 0.0201 (0.0228)  time: 0.1727  data: 0.0124  max mem: 1450
# Epoch: [9]  [ 60/160]  eta: 0:00:17  lr: 0.000001  loss: 0.5114 (0.5366)  loss_classifier: 0.1815 (0.1770)  loss_box_reg: 0.1447 (0.1449)  loss_objectness: 0.1393 (0.1918)  loss_rpn_box_reg: 0.0194 (0.0230)  time: 0.1732  data: 0.0125  max mem: 1450
# Epoch: [9]  [ 70/160]  eta: 0:00:15  lr: 0.000001  loss: 0.5658 (0.5312)  loss_classifier: 0.1815 (0.1766)  loss_box_reg: 0.1469 (0.1446)  loss_objectness: 0.1792 (0.1874)  loss_rpn_box_reg: 0.0192 (0.0226)  time: 0.1725  data: 0.0125  max mem: 1450
# Epoch: [9]  [ 80/160]  eta: 0:00:13  lr: 0.000001  loss: 0.4051 (0.5142)  loss_classifier: 0.1632 (0.1745)  loss_box_reg: 0.1445 (0.1457)  loss_objectness: 0.0669 (0.1725)  loss_rpn_box_reg: 0.0121 (0.0215)  time: 0.1710  data: 0.0124  max mem: 1450
# Epoch: [9]  [ 90/160]  eta: 0:00:12  lr: 0.000001  loss: 0.4382 (0.5172)  loss_classifier: 0.1756 (0.1783)  loss_box_reg: 0.1672 (0.1496)  loss_objectness: 0.0600 (0.1676)  loss_rpn_box_reg: 0.0128 (0.0217)  time: 0.1685  data: 0.0121  max mem: 1450
# Epoch: [9]  [100/160]  eta: 0:00:10  lr: 0.000001  loss: 0.5255 (0.5296)  loss_classifier: 0.1937 (0.1791)  loss_box_reg: 0.1657 (0.1487)  loss_objectness: 0.1187 (0.1796)  loss_rpn_box_reg: 0.0155 (0.0223)  time: 0.1684  data: 0.0120  max mem: 1450
# Epoch: [9]  [110/160]  eta: 0:00:08  lr: 0.000001  loss: 0.4618 (0.5329)  loss_classifier: 0.1720 (0.1808)  loss_box_reg: 0.1512 (0.1512)  loss_objectness: 0.1180 (0.1781)  loss_rpn_box_reg: 0.0181 (0.0228)  time: 0.1695  data: 0.0121  max mem: 1450
# Epoch: [9]  [120/160]  eta: 0:00:06  lr: 0.000001  loss: 0.4284 (0.5279)  loss_classifier: 0.1720 (0.1799)  loss_box_reg: 0.1716 (0.1516)  loss_objectness: 0.1036 (0.1736)  loss_rpn_box_reg: 0.0174 (0.0228)  time: 0.1707  data: 0.0123  max mem: 1450
# Epoch: [9]  [130/160]  eta: 0:00:05  lr: 0.000001  loss: 0.4967 (0.5275)  loss_classifier: 0.1753 (0.1810)  loss_box_reg: 0.1497 (0.1524)  loss_objectness: 0.1006 (0.1716)  loss_rpn_box_reg: 0.0163 (0.0225)  time: 0.1708  data: 0.0127  max mem: 1450
# Epoch: [9]  [140/160]  eta: 0:00:03  lr: 0.000001  loss: 0.5298 (0.5280)  loss_classifier: 0.1904 (0.1830)  loss_box_reg: 0.1744 (0.1556)  loss_objectness: 0.0991 (0.1671)  loss_rpn_box_reg: 0.0163 (0.0222)  time: 0.1713  data: 0.0133  max mem: 1450
# Epoch: [9]  [150/160]  eta: 0:00:01  lr: 0.000001  loss: 0.5198 (0.5259)  loss_classifier: 0.1904 (0.1836)  loss_box_reg: 0.1763 (0.1562)  loss_objectness: 0.0779 (0.1640)  loss_rpn_box_reg: 0.0157 (0.0220)  time: 0.1712  data: 0.0131  max mem: 1450
# Epoch: [9]  [159/160]  eta: 0:00:00  lr: 0.000001  loss: 0.4333 (0.5220)  loss_classifier: 0.1702 (0.1814)  loss_box_reg: 0.1341 (0.1539)  loss_objectness: 0.0613 (0.1650)  loss_rpn_box_reg: 0.0152 (0.0218)  time: 0.1705  data: 0.0124  max mem: 1450
# Epoch: [9] Total time: 0:00:27 (0.1722 s / it)
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:13  model_time: 0.1396 (0.1396)  evaluator_time: 0.0305 (0.0305)  time: 0.3455  data: 0.1716  max mem: 1450
# Test:  [39/40]  eta: 0:00:00  model_time: 0.1338 (0.1340)  evaluator_time: 0.0133 (0.0217)  time: 0.1642  data: 0.0120  max mem: 1450
# Test: Total time: 0:00:07 (0.1760 s / it)
# Averaged stats: model_time: 0.1338 (0.1340)  evaluator_time: 0.0133 (0.0217)
# Accumulating evaluation results...
# DONE (t=0.17s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.109
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.018
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.120

# %%
torch.save(model.state_dict(), PATH_TO_FASTER_RCNN)

# %%
model = getPretrainedModel(num_classes)
model.load_state_dict(torch.load(PATH_TO_FASTER_RCNN))
model.to(device)
evaluate(model, testloader, device=device)
# Out:
# creating index...
# index created!
# Test:  [ 0/40]  eta: 0:00:14  model_time: 0.1400 (0.1400)  evaluator_time: 0.0295 (0.0295)  time: 0.3563  data: 0.1830  max mem: 1451
# Test:  [39/40]  eta: 0:00:00  model_time: 0.1330 (0.1335)  evaluator_time: 0.0130 (0.0162)  time: 0.1632  data: 0.0116  max mem: 1451
# Test: Total time: 0:00:06 (0.1701 s / it)
# Averaged stats: model_time: 0.1330 (0.1335)  evaluator_time: 0.0130 (0.0162)
# Accumulating evaluation results...
# DONE (t=0.18s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.109
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.065
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.018
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.120

# %% [markdown]
# ## Section 4: Test the model

# %%
# %matplotlib inline
import matplotlib.patches as patches
from torchvision import transforms as torchtrans  

def plot_img_bbox(img, target):
    fig, a = plt.subplots(1,1)
    fig.set_size_inches(5,5)
    a.imshow(img)
    for box in (target['boxes']):
        x, y, width, height  = box[0], box[1], box[2]-box[0], box[3]-box[1]
        rect = patches.Rectangle((x, y),
                                 width, height,
                                 linewidth = 2,
                                 edgecolor = 'r',
                                 facecolor = 'none')
        a.add_patch(rect)
    plt.show()

def torch_to_pil(img):
    return torchtrans.ToPILImage()(img).convert('RGB')

def apply_nms(orig_prediction, iou_thresh=0.3):
    keep = torchvision.ops.nms(orig_prediction['boxes'], orig_prediction['scores'], iou_thresh)
    
    final_prediction = orig_prediction
    final_prediction['boxes'] = final_prediction['boxes'][keep]
    final_prediction['scores'] = final_prediction['scores'][keep]
    final_prediction['labels'] = final_prediction['labels'][keep]
    
    return final_prediction

# %%
#TODO: Pick an one image from the test set and print it's precidition as well as the bounding box using above helper functions.
images = next(iter(testloader))
print(images[1])
# Out:
# [{'boxes': tensor([[110., 269., 500., 375.],
#         [ 52., 230., 140., 375.]]), 'labels': tensor([10,  8]), 'area': tensor([41340., 12760.]), 'image_id': 109, 'iscrowd': tensor([0, 0])}, {'boxes': tensor([[133., 250., 274., 424.],
#         [255., 246., 316., 385.],
#         [ 57., 218.,  86., 258.],
#         [ 82., 203., 101., 242.],
#         [100., 176., 156., 280.]]), 'labels': tensor([12, 12, 14, 14, 14]), 'area': tensor([24534.,  8479.,  1160.,   741.,  5824.]), 'image_id': 629, 'iscrowd': tensor([0, 0, 0, 0, 0])}, {'boxes': tensor([[ 75.,  43., 206., 496.],
#         [181.,  62., 211., 132.],
#         [  3.,  27., 248., 394.],
#         [242.,  77., 375., 280.]]), 'labels': tensor([14,  4, 17, 17]), 'area': tensor([59343.,  2100., 89915., 26999.]), 'image_id': 174, 'iscrowd': tensor([0, 0, 0, 0])}, {'boxes': tensor([[ 71., 129., 331., 499.],
#         [171., 196., 330., 486.]]), 'labels': tensor([14, 14]), 'area': tensor([96200., 46110.]), 'image_id': 398, 'iscrowd': tensor([0, 0])}, {'boxes': tensor([[177., 169., 298., 289.]]), 'labels': tensor([16]), 'area': tensor([14520.]), 'image_id': 259, 'iscrowd': tensor([0])}]

# %%
imageIdx = 2
print(images[1][imageIdx])
plot_img_bbox(torch_to_pil(images[0][imageIdx]), images[1][imageIdx])
# Out:
# {'boxes': tensor([[ 75.,  43., 206., 496.],
#         [181.,  62., 211., 132.],
#         [  3.,  27., 248., 394.],
#         [242.,  77., 375., 280.]]), 'labels': tensor([14,  4, 17, 17]), 'area': tensor([59343.,  2100., 89915., 26999.]), 'image_id': 174, 'iscrowd': tensor([0, 0, 0, 0])}

# %%
print(images[0][0].shape)

cpu_device = torch.device("cpu")
model = getPretrainedModel(num_classes)
model.load_state_dict(torch.load(PATH_TO_FASTER_RCNN))
model.to(cpu_device)
model.eval()
output = model(images[0])
# Out:
# torch.Size([3, 480, 480])

# %%
imageIdx= 2
NMS_Output = apply_nms(output[imageIdx], iou_thresh=0.20)
NMS_Output = { k:v.detach().numpy() for k,v in NMS_Output.items() }
print(NMS_Output)
print(images[1][0])
plot_img_bbox(torch_to_pil(images[0][imageIdx]), NMS_Output)
# Out:
# {'boxes': array([[ 95.3826  ,  36.73118 , 291.38113 , 351.29688 ],
#        [  0.      ,  14.254148, 135.79906 , 183.8754  ],
#        [304.20428 ,  66.007225, 468.97107 , 207.87334 ],
#        [241.41878 ,  56.234955, 271.45422 ,  98.91411 ],
#        [128.62    ,  45.706852, 256.15353 , 109.243866],
#        [139.19685 , 212.70729 , 297.10315 , 268.0473  ]], dtype=float32), 'labels': array([14, 14, 14, 14, 14, 14]), 'scores': array([0.7880444 , 0.23700026, 0.21107623, 0.11046779, 0.10744533,
#        0.05266948], dtype=float32)}
# {'boxes': tensor([[110., 269., 500., 375.],
#         [ 52., 230., 140., 375.]]), 'labels': tensor([10,  8]), 'area': tensor([41340., 12760.]), 'image_id': 109, 'iscrowd': tensor([0, 0])}
