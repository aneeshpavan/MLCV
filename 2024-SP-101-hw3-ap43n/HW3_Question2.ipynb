# %% [markdown]
# ## Section 1: Import Libraries and load cifar10 dataset.

# %%
import torch
import torchvision
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt
#import additional libraries if needed

# %%
import os

def load_cifar10_data(batch_size):
  transform = transforms.Compose(
      [transforms.Resize(256),
      transforms.CenterCrop(224),
      transforms.RandomHorizontalFlip(),
      transforms.ToTensor(),
      transforms.Normalize(
          mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]
      )])
    
  trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
  
  trainset = torch.utils.data.Subset(trainset, range(10000))

  cpu_cores = os.cpu_count()

  trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=cpu_cores // 2, pin_memory=True)

  testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
  
  testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=cpu_cores // 2, pin_memory=True)
  
  return trainloader, testloader, trainset

# %%
batch_size = 32
trainloader, testloader, trainset = load_cifar10_data(batch_size)

classes = ('plane', 'car', 'bird', 'cat',
            'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Check the dimensions of a batch:
for images, labels in trainloader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    break
# Out:
# Image batch dimensions: torch.Size([32, 3, 224, 224])
# Image label dimensions: torch.Size([32])

# %% [markdown]
# ## Section 2: Load Pre-trained Model

# %%
from torchvision import models as torchvision_models
model_list = []

# AlexNet
alexnet = torchvision_models.alexnet(pretrained=True)
alexnet.name = 'Alexnet'
model_list.append(alexnet)

# VGG16
VGG16 = torchvision_models.vgg16(pretrained=True)
VGG16.name = 'VGG16'
model_list.append(VGG16)

# ResNet-50
resnet = torchvision_models.resnet50(pretrained=True)
resnet.name = 'Resnet-50'
model_list.append(resnet)

for model in model_list:
    print(f"{model.name} loaded.")
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Alexnet loaded.
# VGG16 loaded.
# Resnet-50 loaded.

# %%
import torch.nn as nn
import torch.optim as optim

for param in alexnet.parameters():
    param.requires_grad = False

# Alex-net
output_layer_index = 6
in_features = alexnet.classifier[output_layer_index].in_features
no_of_cifar_classes = 10
alexnet.classifier[output_layer_index] = nn.Linear(in_features, no_of_cifar_classes)
for param in alexnet.classifier[output_layer_index].parameters():
    param.requires_grad = True

# VGG16
output_layer_index = 6
in_features = VGG16.classifier[output_layer_index].in_features
no_of_cifar_classes = 10
VGG16.classifier[output_layer_index] = nn.Linear(in_features, no_of_cifar_classes)
for param in VGG16.classifier[output_layer_index].parameters():
    param.requires_grad = True

# Resnet-50
in_features = resnet.fc.in_features
no_of_cifar_classes = 10
resnet.fc = nn.Linear(in_features, no_of_cifar_classes)
for param in resnet.fc.parameters():
    param.requires_grad = True

# %% [markdown]
# ## Section 3: Define optimizer and loss criterion

# %%
#TODO: Declare your hyperparameters here
random_seed = 42
learning_rate = 0.001
num_epochs = 8
num_folds = 10

np.random.seed(random_seed)
torch.manual_seed(random_seed)

optimizers = {}
for model in model_list:
    optimizers[model.name] = optim.SGD(model.parameters(), lr=learning_rate * (batch_size / 4), momentum=0.9, weight_decay=1e-4)
    
criterion = nn.CrossEntropyLoss()
foldLen = len(trainset)//num_folds

# %%
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('Device:', DEVICE)
# Out:
# Device: cuda:0

# %% [markdown]
# ## Section 4: Train the model

# %%
def train_model(model, num_epochs, trainloader, testloader, optimizer, criterion):
    epoch_accuracies = []
    for epoch in range(num_epochs):
        running_loss = 0.0
        truePredictions = 0
        totalPredictions = 0
        
        model.train()
        for i, (features, labels) in enumerate(trainloader):
            
            #TODO: Create a training pipeline - compute the model logits, backward prop, and update step.
            inputs, labels = features.to(DEVICE), labels.to(DEVICE)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            _, predicted = torch.max(outputs.data, 1)
            totalPredictions += labels.size(0)
            truePredictions += (predicted == labels).sum().item()
            
            #TODO: Print the accuracy and loss as well.
            running_loss += loss.item()
            
        epoch_loss = running_loss / len(trainloader)
        epoch_acc = 100 * truePredictions / totalPredictions
        epoch_accuracies.append(epoch_acc)
        print(f"Epoch Number [{epoch + 1}/{num_epochs}], Loss Value: {epoch_loss:.4f}, Accuracy this fold: {epoch_acc:.2f}%")
        
    model.eval()
    with torch.no_grad():
        truePredictions = 0
        totalPredictions = 0
        for (features, labels) in testloader:
            images, labels = features.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            totalPredictions += labels.size(0)
            truePredictions += (predicted == labels).sum().item()

        validation_accuracy = 100 * truePredictions / totalPredictions
        print(f"Accuracy for the fold on test data: {validation_accuracy:.2f}%\n")       
        
    train_accuracy = sum(epoch_accuracies) / num_epochs
        
    return train_accuracy, validation_accuracy

# %% [markdown]
# ## Section 5: Test the model

# %%
for model in model_list:
  print(model.name)
  # optimizer
  optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate * (batch_size / 4), momentum=0.9, weight_decay=1e-4)

  DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
  print('Device:', DEVICE)
  model = model.to(DEVICE)

  test_accuracies = []
  train_accuracies = []
  for fold in range(num_folds):
      print(f'Fold-- {fold+1}')
      test_start_index = foldLen * fold
      test_end_index = test_start_index + foldLen
      
      train_indices = list(range(0, test_start_index)) + list(range(test_end_index, len(trainset)))
      test_indices = list(range(test_start_index, test_end_index))
      
      train_sampler = torch.utils.data.sampler.SubsetRandomSampler(train_indices)
      validation_sampler = torch.utils.data.sampler.SubsetRandomSampler(test_indices)

      cpu_cores = os.cpu_count()

      train_loader = torch.utils.data.DataLoader(trainset, batch_size=32, sampler=train_sampler, num_workers=cpu_cores//2, pin_memory=True)
      validation_loader = torch.utils.data.DataLoader(trainset, batch_size=32, sampler=validation_sampler, num_workers=cpu_cores//2, pin_memory=True)

      train_accuracy, validation_accuracy = train_model(model, num_epochs, train_loader, validation_loader, optimizer, criterion)
      test_accuracies.append(validation_accuracy)
      train_accuracies.append(train_accuracy)
      
  avg_validation_accuracy = sum(test_accuracies) / num_folds
  avg_train_accuracy = sum(train_accuracies) / num_folds
  print(f"Accuracy of the network on the train images for {model.name}: {avg_train_accuracy:.2f}%")
  print(f"Accuracy of the network on the 10000 test images for {model.name}: {avg_validation_accuracy:.2f}%")
  print(f"Cross validation done for {model.name}")
# Out:
# Alexnet
# Device: cuda:0
# Fold-- 1
# Epoch Number [1/8], Loss Value: 2.2835, Accuracy this fold: 61.18%
# Epoch Number [2/8], Loss Value: 1.8299, Accuracy this fold: 69.79%
# Epoch Number [3/8], Loss Value: 1.8217, Accuracy this fold: 70.37%
# Epoch Number [4/8], Loss Value: 1.6206, Accuracy this fold: 73.53%
# Epoch Number [5/8], Loss Value: 1.5973, Accuracy this fold: 73.54%
# Epoch Number [6/8], Loss Value: 1.6333, Accuracy this fold: 73.51%
# Epoch Number [7/8], Loss Value: 1.6066, Accuracy this fold: 74.02%
# Epoch Number [8/8], Loss Value: 1.5283, Accuracy this fold: 75.48%
# Accuracy for the fold on test data: 71.70%
#
# Fold-- 2
# Epoch Number [1/8], Loss Value: 1.6222, Accuracy this fold: 74.98%
# Epoch Number [2/8], Loss Value: 1.8187, Accuracy this fold: 73.97%
# Epoch Number [3/8], Loss Value: 1.6270, Accuracy this fold: 74.86%
# Epoch Number [4/8], Loss Value: 1.6727, Accuracy this fold: 74.92%
# Epoch Number [5/8], Loss Value: 1.5699, Accuracy this fold: 76.27%
# Epoch Number [6/8], Loss Value: 1.5011, Accuracy this fold: 76.46%
# Epoch Number [7/8], Loss Value: 1.5912, Accuracy this fold: 76.02%
# Epoch Number [8/8], Loss Value: 1.6058, Accuracy this fold: 76.46%
# Accuracy for the fold on test data: 80.50%
#
# Fold-- 3
# Epoch Number [1/8], Loss Value: 1.6174, Accuracy this fold: 76.38%
# Epoch Number [2/8], Loss Value: 1.5451, Accuracy this fold: 77.43%
# Epoch Number [3/8], Loss Value: 1.5697, Accuracy this fold: 77.03%
# Epoch Number [4/8], Loss Value: 1.5557, Accuracy this fold: 77.29%
# Epoch Number [5/8], Loss Value: 1.4318, Accuracy this fold: 77.67%
# Epoch Number [6/8], Loss Value: 1.3559, Accuracy this fold: 79.08%
# Epoch Number [7/8], Loss Value: 1.4589, Accuracy this fold: 78.14%
# Epoch Number [8/8], Loss Value: 1.3968, Accuracy this fold: 78.07%
# Accuracy for the fold on test data: 78.20%
#
# Fold-- 4
# Epoch Number [1/8], Loss Value: 1.4578, Accuracy this fold: 78.39%
# Epoch Number [2/8], Loss Value: 1.4224, Accuracy this fold: 78.33%
# Epoch Number [3/8], Loss Value: 1.4621, Accuracy this fold: 78.17%
# Epoch Number [4/8], Loss Value: 1.2967, Accuracy this fold: 79.71%
# Epoch Number [5/8], Loss Value: 1.2252, Accuracy this fold: 80.18%
# Epoch Number [6/8], Loss Value: 1.4471, Accuracy this fold: 78.31%
# Epoch Number [7/8], Loss Value: 1.4059, Accuracy this fold: 78.69%
# Epoch Number [8/8], Loss Value: 1.3897, Accuracy this fold: 79.06%
# Accuracy for the fold on test data: 76.90%
#
# Fold-- 5
# Epoch Number [1/8], Loss Value: 1.5069, Accuracy this fold: 78.70%
# Epoch Number [2/8], Loss Value: 1.4111, Accuracy this fold: 79.27%
# Epoch Number [3/8], Loss Value: 1.3744, Accuracy this fold: 79.40%
# Epoch Number [4/8], Loss Value: 1.3783, Accuracy this fold: 79.50%
# Epoch Number [5/8], Loss Value: 1.4502, Accuracy this fold: 79.31%
# Epoch Number [6/8], Loss Value: 1.3305, Accuracy this fold: 79.13%
# Epoch Number [7/8], Loss Value: 1.3994, Accuracy this fold: 79.27%
# Epoch Number [8/8], Loss Value: 1.3377, Accuracy this fold: 79.52%
# Accuracy for the fold on test data: 82.50%
#
# Fold-- 6
# Epoch Number [1/8], Loss Value: 1.3916, Accuracy this fold: 79.48%
# Epoch Number [2/8], Loss Value: 1.2855, Accuracy this fold: 80.49%
# Epoch Number [3/8], Loss Value: 1.2939, Accuracy this fold: 80.17%
# Epoch Number [4/8], Loss Value: 1.2682, Accuracy this fold: 80.40%
# Epoch Number [5/8], Loss Value: 1.3669, Accuracy this fold: 79.69%
# Epoch Number [6/8], Loss Value: 1.3492, Accuracy this fold: 79.50%
# Epoch Number [7/8], Loss Value: 1.3003, Accuracy this fold: 80.49%
# Epoch Number [8/8], Loss Value: 1.3459, Accuracy this fold: 80.00%
# Accuracy for the fold on test data: 82.10%
#
# Fold-- 7
# Epoch Number [1/8], Loss Value: 1.2880, Accuracy this fold: 80.66%
# Epoch Number [2/8], Loss Value: 1.3130, Accuracy this fold: 79.68%
# Epoch Number [3/8], Loss Value: 1.4766, Accuracy this fold: 79.23%
# Epoch Number [4/8], Loss Value: 1.2286, Accuracy this fold: 81.03%
# Epoch Number [5/8], Loss Value: 1.2968, Accuracy this fold: 79.87%
# Epoch Number [6/8], Loss Value: 1.1894, Accuracy this fold: 80.97%
# Epoch Number [7/8], Loss Value: 1.2848, Accuracy this fold: 80.37%
# Epoch Number [8/8], Loss Value: 1.3960, Accuracy this fold: 80.00%
# Accuracy for the fold on test data: 85.80%
#
# Fold-- 8
# Epoch Number [1/8], Loss Value: 1.3556, Accuracy this fold: 80.12%
# Epoch Number [2/8], Loss Value: 1.2563, Accuracy this fold: 81.17%
# Epoch Number [3/8], Loss Value: 1.3482, Accuracy this fold: 80.50%
# Epoch Number [4/8], Loss Value: 1.2372, Accuracy this fold: 80.87%
# Epoch Number [5/8], Loss Value: 1.2884, Accuracy this fold: 80.93%
# Epoch Number [6/8], Loss Value: 1.3488, Accuracy this fold: 80.14%
# Epoch Number [7/8], Loss Value: 1.1467, Accuracy this fold: 81.82%
# Epoch Number [8/8], Loss Value: 1.1753, Accuracy this fold: 81.29%
# Accuracy for the fold on test data: 83.70%
#
# Fold-- 9
# Epoch Number [1/8], Loss Value: 1.3253, Accuracy this fold: 80.38%
# Epoch Number [2/8], Loss Value: 1.2023, Accuracy this fold: 81.67%
# Epoch Number [3/8], Loss Value: 1.3393, Accuracy this fold: 80.27%
# Epoch Number [4/8], Loss Value: 1.3369, Accuracy this fold: 80.53%
# Epoch Number [5/8], Loss Value: 1.2449, Accuracy this fold: 81.77%
# Epoch Number [6/8], Loss Value: 1.2912, Accuracy this fold: 80.67%
# Epoch Number [7/8], Loss Value: 1.3003, Accuracy this fold: 81.12%
# Epoch Number [8/8], Loss Value: 1.1875, Accuracy this fold: 82.13%
# Accuracy for the fold on test data: 84.40%
#
# Fold-- 10
# Epoch Number [1/8], Loss Value: 1.3793, Accuracy this fold: 80.40%
# Epoch Number [2/8], Loss Value: 1.3025, Accuracy this fold: 81.00%
# Epoch Number [3/8], Loss Value: 1.3212, Accuracy this fold: 80.87%
# Epoch Number [4/8], Loss Value: 1.3083, Accuracy this fold: 80.33%
# Epoch Number [5/8], Loss Value: 1.2524, Accuracy this fold: 81.84%
# Epoch Number [6/8], Loss Value: 1.2178, Accuracy this fold: 81.56%
# Epoch Number [7/8], Loss Value: 1.2108, Accuracy this fold: 81.71%
# Epoch Number [8/8], Loss Value: 1.2884, Accuracy this fold: 80.96%
# Accuracy for the fold on test data: 85.10%
#
# Accuracy of the network on the train images for Alexnet: 78.59%
# Accuracy of the network on the 10000 test images for Alexnet: 81.09%
# Cross validation done for Alexnet
# VGG16
# Device: cuda:0
# Fold-- 1
# Epoch Number [1/8], Loss Value: 1.4312, Accuracy this fold: 48.27%
# Epoch Number [2/8], Loss Value: 0.9055, Accuracy this fold: 68.82%
# Epoch Number [3/8], Loss Value: 0.6847, Accuracy this fold: 76.74%
# Epoch Number [4/8], Loss Value: 0.5644, Accuracy this fold: 81.11%
# Epoch Number [5/8], Loss Value: 0.4545, Accuracy this fold: 84.58%
# Epoch Number [6/8], Loss Value: 0.4069, Accuracy this fold: 86.06%
# Epoch Number [7/8], Loss Value: 0.3054, Accuracy this fold: 89.48%
# Epoch Number [8/8], Loss Value: 0.3087, Accuracy this fold: 89.74%
# Accuracy for the fold on test data: 82.30%
#
# Fold-- 2
# Epoch Number [1/8], Loss Value: 0.2827, Accuracy this fold: 90.33%
# Epoch Number [2/8], Loss Value: 0.2638, Accuracy this fold: 91.03%
# Epoch Number [3/8], Loss Value: 0.2213, Accuracy this fold: 92.52%
# Epoch Number [4/8], Loss Value: 0.1698, Accuracy this fold: 94.14%
# Epoch Number [5/8], Loss Value: 0.1789, Accuracy this fold: 93.98%
# Epoch Number [6/8], Loss Value: 0.1526, Accuracy this fold: 95.07%
# Epoch Number [7/8], Loss Value: 0.1424, Accuracy this fold: 95.01%
# Epoch Number [8/8], Loss Value: 0.1300, Accuracy this fold: 95.66%
# Accuracy for the fold on test data: 89.90%
#
# Fold-- 3
# Epoch Number [1/8], Loss Value: 0.1546, Accuracy this fold: 94.83%
# Epoch Number [2/8], Loss Value: 0.0869, Accuracy this fold: 97.24%
# Epoch Number [3/8], Loss Value: 0.1010, Accuracy this fold: 96.82%
# Epoch Number [4/8], Loss Value: 0.1000, Accuracy this fold: 96.81%
# Epoch Number [5/8], Loss Value: 0.0698, Accuracy this fold: 97.70%
# Epoch Number [6/8], Loss Value: 0.0769, Accuracy this fold: 97.48%
# Epoch Number [7/8], Loss Value: 0.0807, Accuracy this fold: 97.40%
# Epoch Number [8/8], Loss Value: 0.0662, Accuracy this fold: 97.87%
# Accuracy for the fold on test data: 96.40%
#
# Fold-- 4
# Epoch Number [1/8], Loss Value: 0.0915, Accuracy this fold: 97.06%
# Epoch Number [2/8], Loss Value: 0.0473, Accuracy this fold: 98.28%
# Epoch Number [3/8], Loss Value: 0.0892, Accuracy this fold: 97.01%
# Epoch Number [4/8], Loss Value: 0.0816, Accuracy this fold: 97.39%
# Epoch Number [5/8], Loss Value: 0.0648, Accuracy this fold: 97.94%
# Epoch Number [6/8], Loss Value: 0.0603, Accuracy this fold: 98.12%
# Epoch Number [7/8], Loss Value: 0.0600, Accuracy this fold: 98.31%
# Epoch Number [8/8], Loss Value: 0.0579, Accuracy this fold: 98.17%
# Accuracy for the fold on test data: 97.90%
#
# Fold-- 5
# Epoch Number [1/8], Loss Value: 0.0460, Accuracy this fold: 98.49%
# Epoch Number [2/8], Loss Value: 0.0240, Accuracy this fold: 99.29%
# Epoch Number [3/8], Loss Value: 0.0564, Accuracy this fold: 98.34%
# Epoch Number [4/8], Loss Value: 0.0359, Accuracy this fold: 98.83%
# Epoch Number [5/8], Loss Value: 0.0303, Accuracy this fold: 98.94%
# Epoch Number [6/8], Loss Value: 0.0467, Accuracy this fold: 98.52%
# Epoch Number [7/8], Loss Value: 0.0406, Accuracy this fold: 98.78%
# Epoch Number [8/8], Loss Value: 0.0352, Accuracy this fold: 98.89%
# Accuracy for the fold on test data: 98.60%
#
# Fold-- 6
# Epoch Number [1/8], Loss Value: 0.0465, Accuracy this fold: 98.48%
# Epoch Number [2/8], Loss Value: 0.0486, Accuracy this fold: 98.47%
# Epoch Number [3/8], Loss Value: 0.0398, Accuracy this fold: 98.64%
# Epoch Number [4/8], Loss Value: 0.0352, Accuracy this fold: 98.87%
# Epoch Number [5/8], Loss Value: 0.0259, Accuracy this fold: 99.27%
# Epoch Number [6/8], Loss Value: 0.0098, Accuracy this fold: 99.78%
# Epoch Number [7/8], Loss Value: 0.0271, Accuracy this fold: 99.04%
# Epoch Number [8/8], Loss Value: 0.0329, Accuracy this fold: 98.92%
# Accuracy for the fold on test data: 98.10%
#
# Fold-- 7
# Epoch Number [1/8], Loss Value: 0.0368, Accuracy this fold: 98.80%
# Epoch Number [2/8], Loss Value: 0.0230, Accuracy this fold: 99.29%
# Epoch Number [3/8], Loss Value: 0.0238, Accuracy this fold: 99.21%
# Epoch Number [4/8], Loss Value: 0.0276, Accuracy this fold: 99.13%
# Epoch Number [5/8], Loss Value: 0.0165, Accuracy this fold: 99.47%
# Epoch Number [6/8], Loss Value: 0.0369, Accuracy this fold: 98.90%
# Epoch Number [7/8], Loss Value: 0.0190, Accuracy this fold: 99.37%
# Epoch Number [8/8], Loss Value: 0.0281, Accuracy this fold: 99.06%
# Accuracy for the fold on test data: 99.10%
#
# Fold-- 8
# Epoch Number [1/8], Loss Value: 0.0244, Accuracy this fold: 99.20%
# Epoch Number [2/8], Loss Value: 0.0068, Accuracy this fold: 99.81%
# Epoch Number [3/8], Loss Value: 0.0191, Accuracy this fold: 99.47%
# Epoch Number [4/8], Loss Value: 0.0163, Accuracy this fold: 99.51%
# Epoch Number [5/8], Loss Value: 0.0077, Accuracy this fold: 99.74%
# Epoch Number [6/8], Loss Value: 0.0119, Accuracy this fold: 99.61%
# Epoch Number [7/8], Loss Value: 0.0201, Accuracy this fold: 99.32%
# Epoch Number [8/8], Loss Value: 0.0170, Accuracy this fold: 99.47%
# Accuracy for the fold on test data: 99.30%
#
# Fold-- 9
# Epoch Number [1/8], Loss Value: 0.0169, Accuracy this fold: 99.44%
# Epoch Number [2/8], Loss Value: 0.0146, Accuracy this fold: 99.54%
# Epoch Number [3/8], Loss Value: 0.0265, Accuracy this fold: 99.07%
# Epoch Number [4/8], Loss Value: 0.0268, Accuracy this fold: 99.11%
# Epoch Number [5/8], Loss Value: 0.0162, Accuracy this fold: 99.54%
# Epoch Number [6/8], Loss Value: 0.0068, Accuracy this fold: 99.77%
# Epoch Number [7/8], Loss Value: 0.0060, Accuracy this fold: 99.77%
# Epoch Number [8/8], Loss Value: 0.0200, Accuracy this fold: 99.50%
# Accuracy for the fold on test data: 99.30%
#
# Fold-- 10
# Epoch Number [1/8], Loss Value: 0.0215, Accuracy this fold: 99.31%
# Epoch Number [2/8], Loss Value: 0.0084, Accuracy this fold: 99.74%
# Epoch Number [3/8], Loss Value: 0.0126, Accuracy this fold: 99.66%
# Epoch Number [4/8], Loss Value: 0.0014, Accuracy this fold: 99.97%
# Epoch Number [5/8], Loss Value: 0.0015, Accuracy this fold: 99.94%
# Epoch Number [6/8], Loss Value: 0.0073, Accuracy this fold: 99.77%
# Epoch Number [7/8], Loss Value: 0.0025, Accuracy this fold: 99.90%
# Epoch Number [8/8], Loss Value: 0.0016, Accuracy this fold: 99.93%
# Accuracy for the fold on test data: 99.90%
#
# Accuracy of the network on the train images for VGG16: 96.20%
# Accuracy of the network on the 10000 test images for VGG16: 96.08%
# Cross validation done for VGG16
# Resnet-50
# Device: cuda:0
# Fold-- 1
# Epoch Number [1/8], Loss Value: 0.9621, Accuracy this fold: 67.81%
# Epoch Number [2/8], Loss Value: 0.5240, Accuracy this fold: 82.40%
# Epoch Number [3/8], Loss Value: 0.3540, Accuracy this fold: 87.93%
# Epoch Number [4/8], Loss Value: 0.2398, Accuracy this fold: 92.00%
# Epoch Number [5/8], Loss Value: 0.2208, Accuracy this fold: 92.71%
# Epoch Number [6/8], Loss Value: 0.1787, Accuracy this fold: 94.08%
# Epoch Number [7/8], Loss Value: 0.1425, Accuracy this fold: 95.51%
# Epoch Number [8/8], Loss Value: 0.1180, Accuracy this fold: 96.13%
# Accuracy for the fold on test data: 90.30%
#
# Fold-- 2
# Epoch Number [1/8], Loss Value: 0.1516, Accuracy this fold: 95.04%
# Epoch Number [2/8], Loss Value: 0.0980, Accuracy this fold: 96.84%
# Epoch Number [3/8], Loss Value: 0.0642, Accuracy this fold: 98.01%
# Epoch Number [4/8], Loss Value: 0.0657, Accuracy this fold: 97.94%
# Epoch Number [5/8], Loss Value: 0.0654, Accuracy this fold: 97.83%
# Epoch Number [6/8], Loss Value: 0.0375, Accuracy this fold: 98.80%
# Epoch Number [7/8], Loss Value: 0.0405, Accuracy this fold: 98.69%
# Epoch Number [8/8], Loss Value: 0.0672, Accuracy this fold: 97.74%
# Accuracy for the fold on test data: 95.60%
#
# Fold-- 3
# Epoch Number [1/8], Loss Value: 0.0992, Accuracy this fold: 96.64%
# Epoch Number [2/8], Loss Value: 0.0557, Accuracy this fold: 98.20%
# Epoch Number [3/8], Loss Value: 0.0305, Accuracy this fold: 99.01%
# Epoch Number [4/8], Loss Value: 0.0179, Accuracy this fold: 99.48%
# Epoch Number [5/8], Loss Value: 0.0365, Accuracy this fold: 98.73%
# Epoch Number [6/8], Loss Value: 0.0131, Accuracy this fold: 99.67%
# Epoch Number [7/8], Loss Value: 0.0098, Accuracy this fold: 99.68%
# Epoch Number [8/8], Loss Value: 0.0297, Accuracy this fold: 99.13%
# Accuracy for the fold on test data: 98.40%
#
# Fold-- 4
# Epoch Number [1/8], Loss Value: 0.0715, Accuracy this fold: 97.38%
# Epoch Number [2/8], Loss Value: 0.0501, Accuracy this fold: 98.36%
# Epoch Number [3/8], Loss Value: 0.0314, Accuracy this fold: 98.82%
# Epoch Number [4/8], Loss Value: 0.0286, Accuracy this fold: 98.98%
# Epoch Number [5/8], Loss Value: 0.0142, Accuracy this fold: 99.54%
# Epoch Number [6/8], Loss Value: 0.0125, Accuracy this fold: 99.67%
# Epoch Number [7/8], Loss Value: 0.0081, Accuracy this fold: 99.72%
# Epoch Number [8/8], Loss Value: 0.0071, Accuracy this fold: 99.80%
# Accuracy for the fold on test data: 99.90%
#
# Fold-- 5
# Epoch Number [1/8], Loss Value: 0.0087, Accuracy this fold: 99.79%
# Epoch Number [2/8], Loss Value: 0.0061, Accuracy this fold: 99.82%
# Epoch Number [3/8], Loss Value: 0.0067, Accuracy this fold: 99.83%
# Epoch Number [4/8], Loss Value: 0.0302, Accuracy this fold: 98.94%
# Epoch Number [5/8], Loss Value: 0.0124, Accuracy this fold: 99.62%
# Epoch Number [6/8], Loss Value: 0.0055, Accuracy this fold: 99.86%
# Epoch Number [7/8], Loss Value: 0.0079, Accuracy this fold: 99.74%
# Epoch Number [8/8], Loss Value: 0.0143, Accuracy this fold: 99.58%
# Accuracy for the fold on test data: 99.70%
#
# Fold-- 6
# Epoch Number [1/8], Loss Value: 0.0282, Accuracy this fold: 99.10%
# Epoch Number [2/8], Loss Value: 0.0149, Accuracy this fold: 99.54%
# Epoch Number [3/8], Loss Value: 0.0070, Accuracy this fold: 99.80%
# Epoch Number [4/8], Loss Value: 0.0041, Accuracy this fold: 99.92%
# Epoch Number [5/8], Loss Value: 0.0052, Accuracy this fold: 99.88%
# Epoch Number [6/8], Loss Value: 0.0148, Accuracy this fold: 99.52%
# Epoch Number [7/8], Loss Value: 0.0055, Accuracy this fold: 99.87%
# Epoch Number [8/8], Loss Value: 0.0086, Accuracy this fold: 99.72%
# Accuracy for the fold on test data: 99.80%
#
# Fold-- 7
# Epoch Number [1/8], Loss Value: 0.0060, Accuracy this fold: 99.81%
# Epoch Number [2/8], Loss Value: 0.0056, Accuracy this fold: 99.86%
# Epoch Number [3/8], Loss Value: 0.0086, Accuracy this fold: 99.73%
# Epoch Number [4/8], Loss Value: 0.0068, Accuracy this fold: 99.82%
# Epoch Number [5/8], Loss Value: 0.0064, Accuracy this fold: 99.79%
# Epoch Number [6/8], Loss Value: 0.0024, Accuracy this fold: 99.96%
# Epoch Number [7/8], Loss Value: 0.0020, Accuracy this fold: 99.97%
# Epoch Number [8/8], Loss Value: 0.0012, Accuracy this fold: 99.99%
# Accuracy for the fold on test data: 99.90%
#
# Fold-- 8
# Epoch Number [1/8], Loss Value: 0.0033, Accuracy this fold: 99.89%
# Epoch Number [2/8], Loss Value: 0.0034, Accuracy this fold: 99.91%
# Epoch Number [3/8], Loss Value: 0.0072, Accuracy this fold: 99.83%
# Epoch Number [4/8], Loss Value: 0.0241, Accuracy this fold: 99.22%
# Epoch Number [5/8], Loss Value: 0.0290, Accuracy this fold: 99.08%
# Epoch Number [6/8], Loss Value: 0.0193, Accuracy this fold: 99.41%
# Epoch Number [7/8], Loss Value: 0.0097, Accuracy this fold: 99.71%
# Epoch Number [8/8], Loss Value: 0.0463, Accuracy this fold: 98.56%
# Accuracy for the fold on test data: 99.10%
#
# Fold-- 9
# Epoch Number [1/8], Loss Value: 0.0497, Accuracy this fold: 98.31%
# Epoch Number [2/8], Loss Value: 0.0308, Accuracy this fold: 99.02%
# Epoch Number [3/8], Loss Value: 0.0159, Accuracy this fold: 99.47%
# Epoch Number [4/8], Loss Value: 0.0052, Accuracy this fold: 99.82%
# Epoch Number [5/8], Loss Value: 0.0026, Accuracy this fold: 99.92%
# Epoch Number [6/8], Loss Value: 0.0029, Accuracy this fold: 99.88%
# Epoch Number [7/8], Loss Value: 0.0018, Accuracy this fold: 99.96%
# Epoch Number [8/8], Loss Value: 0.0011, Accuracy this fold: 100.00%
# Accuracy for the fold on test data: 100.00%
#
# Fold-- 10
# Epoch Number [1/8], Loss Value: 0.0012, Accuracy this fold: 99.99%
# Epoch Number [2/8], Loss Value: 0.0023, Accuracy this fold: 99.96%
# Epoch Number [3/8], Loss Value: 0.0042, Accuracy this fold: 99.92%
# Epoch Number [4/8], Loss Value: 0.0055, Accuracy this fold: 99.87%
# Epoch Number [5/8], Loss Value: 0.0148, Accuracy this fold: 99.56%
# Epoch Number [6/8], Loss Value: 0.0110, Accuracy this fold: 99.63%
# Epoch Number [7/8], Loss Value: 0.0059, Accuracy this fold: 99.83%
# Epoch Number [8/8], Loss Value: 0.0022, Accuracy this fold: 99.94%
# Accuracy for the fold on test data: 99.90%
#
# Accuracy of the network on the train images for Resnet-50: 98.21%
# Accuracy of the network on the 10000 test images for Resnet-50: 98.26%
# Cross validation done for Resnet-50
